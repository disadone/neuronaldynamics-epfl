# %% [markdown]
# # Notes: [Adaptive Exponential Integrate-and-Fire](https://neuronaldynamics.epfl.ch/online/Ch6.S1.html)

# %% [markdown]
# A single equation is, however, ***not sufficient*** to describe the variety of firing patterns that neurons exhibit in response to a step current. We therefore couple the voltage equation to **abstract current variables** $w_k$, each described by a linear differential equation. The set of equations is
#
#
# $$\tau_m \frac{\mathrm{d}u}{\mathrm{d}t}=f(u)-R\sum_k w_k+R I(t)$$
#
# $$\tau_k \frac{\mathrm{d}w_k}{\mathrm{d}t}=a_k(u-u_{rest})-w_k+b_k \tau_k \sum_{t^{(f)}} \delta(t-t^{(f)})$$
#
#
#
# The coupling of voltage to the **adaptation current** $w_k$ is implemented by the parameter $a_k$ and evolves with **time constant** $\tau_k$. The moment $u(t)=\Theta_{reset}$ defines the firing time $t^{(f)}=t$. After firing, integration of the voltage restarts at $u=u_r$. The $\delta$-function in the $w_k$ equations indicates that, during firing, the **adaptation currents** $w_k$ are ***increased by an amount*** $b_k$
#
#
#
# The **Adaptive Exponential Integrate-and-Fire model (AdEx)** consists of such an exponential nonlinearity in the voltage equation coupled to a ***single*** adaptation variable $w$
#
#
# $$\tau_m \frac{\mathrm{d}u}{\mathrm{d}t}=-(u-u_{rest})+\Delta_T\exp\left(\frac{u-\vartheta_{rh}}{\Delta_T}\right)-R w+R I(t)$$
#
# $$\tau_w \frac{\mathrm{d}w}{\mathrm{d}t}=a(u-u_{rest})-w+b \tau_w \sum_{t^{(f)}} \delta(t-t^{(f)})$$
#
# the adaptation variable $w$ is increased by an amount $b$. Adaptation is characterized by two parameters: $a$ couples adaptation to the voltage and is the source of subthreshold adaptation.
#
#
# **Izhikevich model**
#
# $$\tau_m \frac{\mathrm{d}u}{\mathrm{d}t}=-(u-u_{rest})(u-\vartheta)-R w+R I(t)$$
#
# $$\tau_w \frac{\mathrm{d}w}{\mathrm{d}t}=a(u-u_{rest})-w+b \tau_w \sum_{t^{(f)}} \delta(t-t^{(f)})$$
#
# **Leaky model with adaptation**
#
# $$\tau_m \frac{\mathrm{d}u}{\mathrm{d}t}=-(u-u_{rest})-R\sum_k w_k+R I(t)$$
#
# $$\tau_k \frac{\mathrm{d}w_k}{\mathrm{d}t}=a(u-u_{rest})-w_k+b_k \tau_k \sum_{t^{(f)}} \delta(t-t^{(f)})$$

# %% [markdown]
# Table 6.1
#
# <table class="ltx_tabular ltx_centering ltx_align_middle">
# <thead class="ltx_thead">
# <tr class="ltx_tr">
# <th class="ltx_td ltx_align_center ltx_border_t">Type</th>
# <th class="ltx_td ltx_align_center ltx_border_t">Fig.</th>
# <th class="ltx_td ltx_align_center ltx_border_t">
# <span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-1-Frame" tabindex="0" data-mathml="<math class=&quot;ltx_Math&quot; xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; id=&quot;Ch6.T1.m1&quot; alttext=&quot;\tau_{m}&quot; display=&quot;inline&quot;><semantics><msub><mi>&amp;#x3C4;</mi><mi>m</mi></msub><annotation encoding=&quot;application/x-tex&quot;>      \tau_{m}</annotation></semantics></math>" role="presentation" style="position: relative;"><nobr aria-hidden="true"><span class="math ltx_Math" id="Ch6.T1.m1" aria-label="\tau_{m}" style="width: 1.35em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.115em; height: 0px; font-size: 122%;"><span style="position: absolute; clip: rect(1.584em, 1001.12em, 2.52em, -999.997em); top: -2.163em; left: 0em;"><span class="mrow" id="MathJax-Span-2"><span class="semantics" id="MathJax-Span-3"><span class="msub" id="MathJax-Span-4"><span style="display: inline-block; position: relative; width: 1.115em; height: 0px;"><span style="position: absolute; clip: rect(3.399em, 1000.53em, 4.16em, -999.997em); top: -3.978em; left: 0em;"><span class="mi" id="MathJax-Span-5" style="font-family: MathJax_Math; font-style: italic;">τ<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.061em;"></span></span><span style="display: inline-block; width: 0px; height: 3.984em;"></span></span><span style="position: absolute; top: -3.803em; left: 0.413em;"><span class="mi" id="MathJax-Span-6" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">m</span><span style="display: inline-block; width: 0px; height: 3.984em;"></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.169em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.282em; border-left: 0px solid; width: 0px; height: 0.861em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math class="ltx_Math" xmlns="http://www.w3.org/1998/Math/MathML" id="Ch6.T1.m1" alttext="\tau_{m}" display="inline"><semantics><msub><mi>τ</mi><mi>m</mi></msub><annotation encoding="application/x-tex">      \tau_{m}</annotation></semantics></math></span></span><script type="math/mml" id="MathJax-Element-1"><math id="Ch6.T1.m1" class="ltx_Math" alttext="\tau_{m}" display="inline"><semantics><msub><mi>τ</mi><mi>m</mi></msub><annotation encoding="application/x-tex">\tau_{m}</annotation></semantics></math></script> (ms)</th>
# <th class="ltx_td ltx_align_center ltx_border_t">a (nS)</th>
# <th class="ltx_td ltx_align_center ltx_border_t">
# <span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-2-Frame" tabindex="0" data-mathml="<math class=&quot;ltx_Math&quot; xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; id=&quot;Ch6.T1.m2&quot; alttext=&quot;\tau_{w}&quot; display=&quot;inline&quot;><semantics><msub><mi>&amp;#x3C4;</mi><mi>w</mi></msub><annotation encoding=&quot;application/x-tex&quot;>      \tau_{w}</annotation></semantics></math>" role="presentation" style="position: relative;"><nobr aria-hidden="true"><span class="math ltx_Math" id="Ch6.T1.m2" aria-label="\tau_{w}" style="width: 1.232em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.998em; height: 0px; font-size: 122%;"><span style="position: absolute; clip: rect(1.584em, 1001em, 2.52em, -999.997em); top: -2.163em; left: 0em;"><span class="mrow" id="MathJax-Span-8"><span class="semantics" id="MathJax-Span-9"><span class="msub" id="MathJax-Span-10"><span style="display: inline-block; position: relative; width: 0.998em; height: 0px;"><span style="position: absolute; clip: rect(3.399em, 1000.53em, 4.16em, -999.997em); top: -3.978em; left: 0em;"><span class="mi" id="MathJax-Span-11" style="font-family: MathJax_Math; font-style: italic;">τ<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.061em;"></span></span><span style="display: inline-block; width: 0px; height: 3.984em;"></span></span><span style="position: absolute; top: -3.803em; left: 0.413em;"><span class="mi" id="MathJax-Span-12" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">w</span><span style="display: inline-block; width: 0px; height: 3.984em;"></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.169em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.282em; border-left: 0px solid; width: 0px; height: 0.861em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math class="ltx_Math" xmlns="http://www.w3.org/1998/Math/MathML" id="Ch6.T1.m2" alttext="\tau_{w}" display="inline"><semantics><msub><mi>τ</mi><mi>w</mi></msub><annotation encoding="application/x-tex">      \tau_{w}</annotation></semantics></math></span></span><script type="math/mml" id="MathJax-Element-2"><math id="Ch6.T1.m2" class="ltx_Math" alttext="\tau_{w}" display="inline"><semantics><msub><mi>τ</mi><mi>w</mi></msub><annotation encoding="application/x-tex">\tau_{w}</annotation></semantics></math></script> (ms)</th>
# <th class="ltx_td ltx_align_center ltx_border_t">
# <span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-3-Frame" tabindex="0" data-mathml="<math class=&quot;ltx_Math&quot; xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; id=&quot;Ch6.T1.m3&quot; alttext=&quot;b&quot; display=&quot;inline&quot;><semantics><mi>b</mi><annotation encoding=&quot;application/x-tex&quot;>      b</annotation></semantics></math>" role="presentation" style="position: relative;"><nobr aria-hidden="true"><span class="math ltx_Math" id="Ch6.T1.m3" aria-label="b" style="width: 0.53em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.413em; height: 0px; font-size: 122%;"><span style="position: absolute; clip: rect(1.291em, 1000.41em, 2.345em, -999.997em); top: -2.163em; left: 0em;"><span class="mrow" id="MathJax-Span-14"><span class="semantics" id="MathJax-Span-15"><span class="mi" id="MathJax-Span-16" style="font-family: MathJax_Math; font-style: italic;">b</span></span></span><span style="display: inline-block; width: 0px; height: 2.169em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.068em; border-left: 0px solid; width: 0px; height: 1.004em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math class="ltx_Math" xmlns="http://www.w3.org/1998/Math/MathML" id="Ch6.T1.m3" alttext="b" display="inline"><semantics><mi>b</mi><annotation encoding="application/x-tex">      b</annotation></semantics></math></span></span><script type="math/mml" id="MathJax-Element-3"><math id="Ch6.T1.m3" class="ltx_Math" alttext="b" display="inline"><semantics><mi>b</mi><annotation encoding="application/x-tex">b</annotation></semantics></math></script> (pA)</th>
# <th class="ltx_td ltx_align_center ltx_border_t">
# <span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-4-Frame" tabindex="0" data-mathml="<math class=&quot;ltx_Math&quot; xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; id=&quot;Ch6.T1.m4&quot; alttext=&quot;u_{r}&quot; display=&quot;inline&quot;><semantics><msub><mi>u</mi><mi>r</mi></msub><annotation encoding=&quot;application/x-tex&quot;>      u_{r}</annotation></semantics></math>" role="presentation" style="position: relative;"><nobr aria-hidden="true"><span class="math ltx_Math" id="Ch6.T1.m4" aria-label="u_{r}" style="width: 1.174em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.94em; height: 0px; font-size: 122%;"><span style="position: absolute; clip: rect(1.525em, 1000.94em, 2.52em, -999.997em); top: -2.163em; left: 0em;"><span class="mrow" id="MathJax-Span-18"><span class="semantics" id="MathJax-Span-19"><span class="msub" id="MathJax-Span-20"><span style="display: inline-block; position: relative; width: 0.94em; height: 0px;"><span style="position: absolute; clip: rect(3.34em, 1000.53em, 4.16em, -999.997em); top: -3.978em; left: 0em;"><span class="mi" id="MathJax-Span-21" style="font-family: MathJax_Math; font-style: italic;">u</span><span style="display: inline-block; width: 0px; height: 3.984em;"></span></span><span style="position: absolute; top: -3.803em; left: 0.588em;"><span class="mi" id="MathJax-Span-22" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">r</span><span style="display: inline-block; width: 0px; height: 3.984em;"></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.169em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.282em; border-left: 0px solid; width: 0px; height: 0.861em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math class="ltx_Math" xmlns="http://www.w3.org/1998/Math/MathML" id="Ch6.T1.m4" alttext="u_{r}" display="inline"><semantics><msub><mi>u</mi><mi>r</mi></msub><annotation encoding="application/x-tex">      u_{r}</annotation></semantics></math></span></span><script type="math/mml" id="MathJax-Element-4"><math id="Ch6.T1.m4" class="ltx_Math" alttext="u_{r}" display="inline"><semantics><msub><mi>u</mi><mi>r</mi></msub><annotation encoding="application/x-tex">u_{r}</annotation></semantics></math></script> (mV)</th>
# </tr>
# </thead>
# <tbody class="ltx_tbody">
# <tr class="ltx_tr">
# <td class="ltx_td ltx_align_center ltx_border_t">Tonic</td>
# <td class="ltx_td ltx_align_center ltx_border_t">
# <a href="#Ch6.F3" title="Fig.&nbsp;6.3 ‣ 6.2.1 Classification of Firing Patterns ‣ 6.2 Firing Patterns ‣ Chapter&nbsp;6 Adaptation and Firing Patterns ‣ Part&nbsp;II Generalized Integrate-and-Fire Neurons ‣ Neuronal Dynamics – From Single Neurons to Networks
# and Models of Cognition" class="ltx_ref"><span class="ltx_text ltx_ref_tag">6.3</span></a>A</td>
# <td class="ltx_td ltx_align_center ltx_border_t">20</td>
# <td class="ltx_td ltx_align_center ltx_border_t">0.0</td>
# <td class="ltx_td ltx_align_center ltx_border_t">30.0</td>
# <td class="ltx_td ltx_align_center ltx_border_t">60</td>
# <td class="ltx_td ltx_align_center ltx_border_t">-55</td>
# </tr>
# <tr class="ltx_tr">
# <td class="ltx_td ltx_align_center">Adapting</td>
# <td class="ltx_td ltx_align_center">
# <a href="#Ch6.F3" title="Fig.&nbsp;6.3 ‣ 6.2.1 Classification of Firing Patterns ‣ 6.2 Firing Patterns ‣ Chapter&nbsp;6 Adaptation and Firing Patterns ‣ Part&nbsp;II Generalized Integrate-and-Fire Neurons ‣ Neuronal Dynamics – From Single Neurons to Networks
# and Models of Cognition" class="ltx_ref"><span class="ltx_text ltx_ref_tag">6.3</span></a>B</td>
# <td class="ltx_td ltx_align_center">20</td>
# <td class="ltx_td ltx_align_center">0.0</td>
# <td class="ltx_td ltx_align_center">100</td>
# <td class="ltx_td ltx_align_center">5.0</td>
# <td class="ltx_td ltx_align_center">-55</td>
# </tr>
# <tr class="ltx_tr">
# <td class="ltx_td ltx_align_center">Init. burst</td>
# <td class="ltx_td ltx_align_center">
# <a href="#Ch6.F4" title="Fig.&nbsp;6.4 ‣ 6.2.2 Phase plane analysis
# of non-linear integrate-and-fire models in two dimensions ‣ 6.2 Firing Patterns ‣ Chapter&nbsp;6 Adaptation and Firing Patterns ‣ Part&nbsp;II Generalized Integrate-and-Fire Neurons ‣ Neuronal Dynamics – From Single Neurons to Networks
# and Models of Cognition" class="ltx_ref"><span class="ltx_text ltx_ref_tag">6.4</span></a>A</td>
# <td class="ltx_td ltx_align_center">5.0</td>
# <td class="ltx_td ltx_align_center">0.5</td>
# <td class="ltx_td ltx_align_center">100</td>
# <td class="ltx_td ltx_align_center">7.0</td>
# <td class="ltx_td ltx_align_center">-51</td>
# </tr>
# <tr class="ltx_tr">
# <td class="ltx_td ltx_align_center">Bursting</td>
# <td class="ltx_td ltx_align_center">
# <a href="#Ch6.F4" title="Fig.&nbsp;6.4 ‣ 6.2.2 Phase plane analysis
# of non-linear integrate-and-fire models in two dimensions ‣ 6.2 Firing Patterns ‣ Chapter&nbsp;6 Adaptation and Firing Patterns ‣ Part&nbsp;II Generalized Integrate-and-Fire Neurons ‣ Neuronal Dynamics – From Single Neurons to Networks
# and Models of Cognition" class="ltx_ref"><span class="ltx_text ltx_ref_tag">6.4</span></a>C</td>
# <td class="ltx_td ltx_align_center">5.0</td>
# <td class="ltx_td ltx_align_center">-0.5</td>
# <td class="ltx_td ltx_align_center">100</td>
# <td class="ltx_td ltx_align_center">7.0</td>
# <td class="ltx_td ltx_align_center">-46</td>
# </tr>
# <tr class="ltx_tr">
# <td class="ltx_td ltx_align_center">Irregular</td>
# <td class="ltx_td ltx_align_center">
# <a href="#Ch6.F5" title="Fig.&nbsp;6.5 ‣ 6.2.2 Phase plane analysis
# of non-linear integrate-and-fire models in two dimensions ‣ 6.2 Firing Patterns ‣ Chapter&nbsp;6 Adaptation and Firing Patterns ‣ Part&nbsp;II Generalized Integrate-and-Fire Neurons ‣ Neuronal Dynamics – From Single Neurons to Networks
# and Models of Cognition" class="ltx_ref"><span class="ltx_text ltx_ref_tag">6.5</span></a>A</td>
# <td class="ltx_td ltx_align_center">9.9</td>
# <td class="ltx_td ltx_align_center">-0.5</td>
# <td class="ltx_td ltx_align_center">100</td>
# <td class="ltx_td ltx_align_center">7.0</td>
# <td class="ltx_td ltx_align_center">-46</td>
# </tr>
# <tr class="ltx_tr">
# <td class="ltx_td ltx_align_center">Transient</td>
# <td class="ltx_td ltx_align_center">
# <a href="#Ch6.F9" title="Fig.&nbsp;6.9 ‣ 6.2.4 Exploring the Space of Subthreshold Parameters ‣ 6.2 Firing Patterns ‣ Chapter&nbsp;6 Adaptation and Firing Patterns ‣ Part&nbsp;II Generalized Integrate-and-Fire Neurons ‣ Neuronal Dynamics – From Single Neurons to Networks
# and Models of Cognition" class="ltx_ref"><span class="ltx_text ltx_ref_tag">6.9</span></a>A</td>
# <td class="ltx_td ltx_align_center">10</td>
# <td class="ltx_td ltx_align_center">1.0</td>
# <td class="ltx_td ltx_align_center">100</td>
# <td class="ltx_td ltx_align_center">10</td>
# <td class="ltx_td ltx_align_center">-60</td>
# </tr>
# <tr class="ltx_tr">
# <td class="ltx_td ltx_align_center ltx_border_b">Delayed</td>
# <td class="ltx_td ltx_align_center ltx_border_b">
# <span class="ltx_text ltx_ref_tag">&nbsp;</span></td>
# <td class="ltx_td ltx_align_center ltx_border_b">5.0</td>
# <td class="ltx_td ltx_align_center ltx_border_b">-1.0</td>
# <td class="ltx_td ltx_align_center ltx_border_b">100</td>
# <td class="ltx_td ltx_align_center ltx_border_b">10</td>
# <td class="ltx_td ltx_align_center ltx_border_b">-60</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# # Codes: [AdEx: the Adaptive Exponential Integrate-and-Fire model](https://neuronaldynamics-exercises.readthedocs.io/en/latest/exercises/adex-model.html)

# %%
# %matplotlib inline
import brian2 as b2
from neurodynex.adex_model import AdEx
from neurodynex.tools import plot_tools, input_factory
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,5]

# %%
AdEx.simulate_AdEx_neuron?

# %%
current = input_factory.get_step_current(10, 250, 1. * b2.ms, 65.0 * b2.pA)
state_monitor, spike_monitor = AdEx.simulate_AdEx_neuron(I_stim=current, simulation_time=400 * b2.ms)
plot_tools.plot_voltage_and_current_traces(state_monitor, current)
print("nr of spikes: {}".format(spike_monitor.count[0]))
# AdEx.plot_adex_state(state_monitor)
# Out:
# nr of spikes: 10

# %% [markdown]
# ## Question: Firing pattern

# %%
# object 1

# %% [markdown]
# This seems to be burst-adapting firing pattern with high amplitude

# %%
# object 2

#tonic
current = input_factory.get_step_current(10, 250, 1. * b2.ms, 65.0 * b2.pA)
state_monitor, spike_monitor = AdEx.simulate_AdEx_neuron(
    I_stim=current,
    simulation_time=400 * b2.ms,
    tau_m=20*b2.ms,
    a=0.0*b2.nS,
    tau_w=30*b2.ms,
    b=60*b2.pA,
    v_reset=-55*b2.mV
)
plot_tools.plot_voltage_and_current_traces(state_monitor, current)
print("nr of spikes: {}".format(spike_monitor.count[0]))
# AdEx.plot_adex_state(state_monitor)
# Out:
# nr of spikes: 4

# %%
#Adapting
current = input_factory.get_step_current(10, 250, 1. * b2.ms, 65.0 * b2.pA)
state_monitor, spike_monitor = AdEx.simulate_AdEx_neuron(
    I_stim=current,
    simulation_time=400 * b2.ms,
    tau_m=20*b2.ms,
    a=0.0*b2.nS,
    tau_w=100*b2.ms,
    b=5*b2.pA,
    v_reset=-55*b2.mV
)
plot_tools.plot_voltage_and_current_traces(state_monitor, current)
print("nr of spikes: {}".format(spike_monitor.count[0]))
# AdEx.plot_adex_state(state_monitor)
# Out:
# nr of spikes: 10

# %%
#Init. burst
current = input_factory.get_step_current(10, 250, 1. * b2.ms, 65.0 * b2.pA)
state_monitor, spike_monitor = AdEx.simulate_AdEx_neuron(
    I_stim=current,
    simulation_time=400 * b2.ms,
    tau_m=5*b2.ms,
    a=0.5*b2.nS,
    tau_w=100*b2.ms,
    b=5*b2.pA,
    v_reset=-51*b2.mV
)
plot_tools.plot_voltage_and_current_traces(state_monitor, current)
print("nr of spikes: {}".format(spike_monitor.count[0]))
# AdEx.plot_adex_state(state_monitor)
# Out:
# nr of spikes: 13

# %%
# Bursting
current = input_factory.get_step_current(10, 250, 1. * b2.ms, 65.0 * b2.pA)
state_monitor, spike_monitor = AdEx.simulate_AdEx_neuron(
    I_stim=current,
    simulation_time=400 * b2.ms,
    tau_m=5*b2.ms,
    a=-0.5*b2.nS,
    tau_w=100*b2.ms,
    b=5*b2.pA,
    v_reset=-46*b2.mV
)
plot_tools.plot_voltage_and_current_traces(state_monitor, current)
print("nr of spikes: {}".format(spike_monitor.count[0]))
# AdEx.plot_adex_state(state_monitor)
# Out:
# nr of spikes: 29

# %%
# Irregular
current = input_factory.get_step_current(10, 250, 1. * b2.ms, 65.0 * b2.pA)
state_monitor, spike_monitor = AdEx.simulate_AdEx_neuron(
    I_stim=current,
    simulation_time=400 * b2.ms,
    tau_m=9.9*b2.ms,
    a=-0.5*b2.nS,
    tau_w=100*b2.ms,
    b=5*b2.pA,
    v_reset=-46*b2.mV
)
plot_tools.plot_voltage_and_current_traces(state_monitor, current)
print("nr of spikes: {}".format(spike_monitor.count[0]))
# AdEx.plot_adex_state(state_monitor)
# Out:
# nr of spikes: 26

# %%
# Transient
current = input_factory.get_step_current(10, 250, 1. * b2.ms, 65.0 * b2.pA)
state_monitor, spike_monitor = AdEx.simulate_AdEx_neuron(
    I_stim=current,
    simulation_time=400 * b2.ms,
    tau_m=10*b2.ms,
    a=1*b2.nS,
    tau_w=100*b2.ms,
    b=10*b2.pA,
    v_reset=-60*b2.mV
)
plot_tools.plot_voltage_and_current_traces(state_monitor, current)
print("nr of spikes: {}".format(spike_monitor.count[0]))
# AdEx.plot_adex_state(state_monitor)
# Out:
# nr of spikes: 5

# %%
# Delayed
current = input_factory.get_step_current(10, 250, 1. * b2.ms, 65.0 * b2.pA)
state_monitor, spike_monitor = AdEx.simulate_AdEx_neuron(
    I_stim=current,
    simulation_time=400 * b2.ms,
    tau_m=5*b2.ms,
    a=-1*b2.nS,
    tau_w=100*b2.ms,
    b=10*b2.pA,
    v_reset=-60*b2.mV
)
plot_tools.plot_voltage_and_current_traces(state_monitor, current)
print("nr of spikes: {}".format(spike_monitor.count[0]))
# AdEx.plot_adex_state(state_monitor)
# Out:
# nr of spikes: 13

# %%
# object 3
plt.rcParams['figure.figsize'] = [12,10]
AdEx.plot_adex_state?

# %%
#tonic
current = input_factory.get_step_current(10, 250, 1. * b2.ms, 65.0 * b2.pA)
state_monitor, spike_monitor = AdEx.simulate_AdEx_neuron(
    I_stim=current,
    simulation_time=400 * b2.ms,
    tau_m=20*b2.ms,
    a=0.0*b2.nS,
    tau_w=30*b2.ms,
    b=60*b2.pA,
    v_reset=-55*b2.mV
)
#plot_tools.plot_voltage_and_current_traces(state_monitor, current)
print("nr of spikes: {}".format(spike_monitor.count[0]))
AdEx.plot_adex_state(state_monitor)
# Out:
# nr of spikes: 4

# %%
# Adapting
current = input_factory.get_step_current(10, 250, 1. * b2.ms, 65.0 * b2.pA)
state_monitor, spike_monitor = AdEx.simulate_AdEx_neuron(
    I_stim=current,
    simulation_time=400 * b2.ms,
    tau_m=20*b2.ms,
    a=0.0*b2.nS,
    tau_w=100*b2.ms,
    b=5*b2.pA,
    v_reset=-55*b2.mV
)
#plot_tools.plot_voltage_and_current_traces(state_monitor, current)
print("nr of spikes: {}".format(spike_monitor.count[0]))
AdEx.plot_adex_state(state_monitor)
# Out:
# nr of spikes: 10

# %%
MEMBRANE_TIME_SCALE_tau_m = 5 * b2.ms
MEMBRANE_RESISTANCE_R = 500*b2.Mohm
V_REST = -70.0 * b2.mV
V_RESET = -51.0 * b2.mV
RHEOBASE_THRESHOLD_v_rh = -50.0 * b2.mV
SHARPNESS_delta_T = 2.0 * b2.mV
ADAPTATION_VOLTAGE_COUPLING_a = 0.5 * b2.nS
ADAPTATION_TIME_CONSTANT_tau_w = 100.0 * b2.ms
SPIKE_TRIGGERED_ADAPTATION_INCREMENT_b = 7.0 * b2.pA

# %% [markdown]
# ## Exercise: phase plane and nullclines

# %%
AdEx.simulate_AdEx_neuron?

# %%
# object 1
plt.rcParams['figure.figsize'] = [12,10]
current = input_factory.get_step_current(10, 250, 1. * b2.ms, 0 * b2.pA)
state_monitor, spike_monitor = AdEx.simulate_AdEx_neuron(
    I_stim=current,
    simulation_time=400 * b2.ms,
    tau_m=MEMBRANE_TIME_SCALE_tau_m,
    a=ADAPTATION_VOLTAGE_COUPLING_a,
    tau_w=ADAPTATION_TIME_CONSTANT_tau_w,
    b=SPIKE_TRIGGERED_ADAPTATION_INCREMENT_b,
    v_rest=V_REST,
    delta_T=SHARPNESS_delta_T,
    v_rheobase=RHEOBASE_THRESHOLD_v_rh
)
#plot_tools.plot_voltage_and_current_traces(state_monitor, current)
print("nr of spikes: {}".format(spike_monitor.count[0]))
AdEx.plot_adex_state(state_monitor)
# Out:
# nr of spikes: 0

# %%
# object 2
plt.rcParams['figure.figsize'] = [12,10]
current = input_factory.get_step_current(10, 250, 1. * b2.ms, 0 * b2.pA)
state_monitor, spike_monitor = AdEx.simulate_AdEx_neuron(
    I_stim=current,
    simulation_time=400 * b2.ms,
    tau_m=MEMBRANE_TIME_SCALE_tau_m,
    a=ADAPTATION_VOLTAGE_COUPLING_a+0.5*b2.nS,
    tau_w=ADAPTATION_TIME_CONSTANT_tau_w,
    b=SPIKE_TRIGGERED_ADAPTATION_INCREMENT_b,
    v_rest=V_REST,
    delta_T=SHARPNESS_delta_T,
    v_rheobase=RHEOBASE_THRESHOLD_v_rh
)
#plot_tools.plot_voltage_and_current_traces(state_monitor, current)
print("nr of spikes: {}".format(spike_monitor.count[0]))
AdEx.plot_adex_state(state_monitor)
# Out:
# nr of spikes: 0

# %%
# object 3
current = input_factory.get_step_current(10, 250, 1. * b2.ms, 50 * b2.pA)
state_monitor, spike_monitor = AdEx.simulate_AdEx_neuron(
    I_stim=current,
    simulation_time=400 * b2.ms,
    tau_m=MEMBRANE_TIME_SCALE_tau_m,
    a=ADAPTATION_VOLTAGE_COUPLING_a,
    tau_w=ADAPTATION_TIME_CONSTANT_tau_w,
    b=SPIKE_TRIGGERED_ADAPTATION_INCREMENT_b,
    v_rest=V_REST,
    delta_T=SHARPNESS_delta_T,
    v_rheobase=RHEOBASE_THRESHOLD_v_rh
)
#plot_tools.plot_voltage_and_current_traces(state_monitor, current)
print("nr of spikes: {}".format(spike_monitor.count[0]))
AdEx.plot_adex_state(state_monitor)
# Out:
# nr of spikes: 4

# %%
# object 4
current = input_factory.get_step_current(10, 250, 1. * b2.ms, 50 * b2.pA)
state_monitor, spike_monitor = AdEx.simulate_AdEx_neuron(
    I_stim=current,
    simulation_time=400 * b2.ms,
    tau_m=MEMBRANE_TIME_SCALE_tau_m,
    a=ADAPTATION_VOLTAGE_COUPLING_a,
    tau_w=ADAPTATION_TIME_CONSTANT_tau_w,
    b=SPIKE_TRIGGERED_ADAPTATION_INCREMENT_b,
    v_rest=V_REST,
    delta_T=SHARPNESS_delta_T,
    v_rheobase=RHEOBASE_THRESHOLD_v_rh
)
#plot_tools.plot_voltage_and_current_traces(state_monitor, current)
print("nr of spikes: {}".format(spike_monitor.count[0]))
AdEx.plot_adex_state(state_monitor)
# Out:
# nr of spikes: 4

# %%
# object 5
current = input_factory.get_step_current(10, 250, 1. * b2.ms, 50 * b2.pA)
state_monitor, spike_monitor = AdEx.simulate_AdEx_neuron(
    I_stim=current,
    simulation_time=400 * b2.ms,
    tau_m=MEMBRANE_TIME_SCALE_tau_m,
    a=ADAPTATION_VOLTAGE_COUPLING_a,
    tau_w=ADAPTATION_TIME_CONSTANT_tau_w*2,
    b=SPIKE_TRIGGERED_ADAPTATION_INCREMENT_b,
    v_rest=V_REST,
    delta_T=SHARPNESS_delta_T,
    v_rheobase=RHEOBASE_THRESHOLD_v_rh
)
#plot_tools.plot_voltage_and_current_traces(state_monitor, current)
print("nr of spikes: {}".format(spike_monitor.count[0]))
AdEx.plot_adex_state(state_monitor)
# Out:
# nr of spikes: 3

# %% [markdown]
# ### Question:

# %%
# object 1
current = input_factory.get_step_current(10, 250, 1. * b2.ms, 50 * b2.pA)
state_monitor, spike_monitor = AdEx.simulate_AdEx_neuron(
    I_stim=current,
    simulation_time=400 * b2.ms,
    tau_m=MEMBRANE_TIME_SCALE_tau_m,
    a=0.01*b2.nS,
    tau_w=ADAPTATION_TIME_CONSTANT_tau_w*2,
    b=SPIKE_TRIGGERED_ADAPTATION_INCREMENT_b*2,
    v_rest=V_REST,
    delta_T=SHARPNESS_delta_T,
    v_rheobase=RHEOBASE_THRESHOLD_v_rh
)
#plot_tools.plot_voltage_and_current_traces(state_monitor, current)
print("nr of spikes: {}".format(spike_monitor.count[0]))
AdEx.plot_adex_state(state_monitor)
# Out:
# nr of spikes: 3

# %%
# object 1
current = input_factory.get_step_current(10, 250, 1. * b2.ms, 50 * b2.pA)
state_monitor, spike_monitor = AdEx.simulate_AdEx_neuron(
    I_stim=current,
    simulation_time=400 * b2.ms,
    tau_m=MEMBRANE_TIME_SCALE_tau_m,
    a=0.01*b2.nS,
    tau_w=ADAPTATION_TIME_CONSTANT_tau_w*0.5,
    b=SPIKE_TRIGGERED_ADAPTATION_INCREMENT_b*0.5,
    v_rest=V_REST,
    delta_T=SHARPNESS_delta_T,
    v_rheobase=RHEOBASE_THRESHOLD_v_rh
)
#plot_tools.plot_voltage_and_current_traces(state_monitor, current)
print("nr of spikes: {}".format(spike_monitor.count[0]))
AdEx.plot_adex_state(state_monitor)
# Out:
# nr of spikes: 18

# %% [markdown]
# ### Question:

# %% [markdown]
# http://link.springer.com/article/10.1007/s00422-008-0264-7
